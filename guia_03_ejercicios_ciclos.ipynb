# %% [markdown]
# # PRELIMINARES
#
# Una estructura de control iterativa ó ciclo, permite realizar varias veces el mismo conjunto de operaciones. El ciclo se repite mientras se cumple alguna condición lógica ó se itera sobre un objeto.
#
# En Python existen dos tipos de estructuras de repetición (ó iterativas): **while** y **for**.
#
# #### Ciclos con estructura de control While
#
# La estructura **w****hile** evalúa una condición lógica antes de comenzar cada iteración. Si la condición es verdadera, entonces se ejecutan las instrucciones que están dentro de la estructura **w****hile**. En caso contrario, el ciclo termina y se sigue con la ejecución de las instrucciones escritas fuera del ciclo. Las instrucciones que se consideran dentro del ciclo son aquellas que están tabuladas de tal forma que se encuentran a la derecha de la palabra reservada **while**.
#
# La sintaxis de la estructura **while** en Python es la siguiente:
#
# while (condición):
#    <instrucciones del while>
# <primera instrucción fuera del while>
#
# Es decir, el conjunto de instrucciones se repetirá **mientras** la condición sea verdadera. Si la condición es falsa ya desde un principio, el conjunto de instrucciones no se ejecuta nunca.
#
# Por ejemplo, el siguiente código informa si el número ingresado por teclado por el usuario es positivo ó negativo, y se detiene cuando el usuario ingresa el número 0:
#
# numeroUsuario=int(input("Ingresa un número, si quieres terminar ingresa el 0: "))
#
# while (numeroUsuario!=0):
#
# if (numeroUsuario>0):
#
# print("Es positivo")
#
# else:
#
# print("Es negativo")
#
# numeroUsuario=int(input("Ingresa otro número (0 para terminar): "))
#
# print("Fin del ciclo Mientras")
#
# En este ejemplo, si se ingresa 0 la primera vez, la condición (numero!=0) será falsa. Por lo tanto, ni siquiera entra al bloque del **Mientras**, saliendo del ciclo y continuando con la siguiente instrucción que es:
# print("Fin del ciclo Mientras")
#
# Repetición con instrucción for
#
# Una estructura de repetición **for**, permite iterar una ó más instrucciones. El número de veces que se repiten las instrucciones está definido por una variable de control (normalmente llamada contador). La sintaxis es la siguiente:
#
# for nombreVariable in range(valorInicial,valorFinal,ModificaciónRango):
#
# <instrucciones>
#
# Donde nombreVariable es el nombre de la variable de control (normalmente se le llama contador), **range****(****valorInicial,valorFinal,ModificaciónContador****)**  genera los números sobre los cuales iterará la variable nombreVariable. Los números generado por la función range van desde <valorInicial> hasta <valorFinal>-1, con un incremento ó decremento de <ModificaciónRango>.
#
# Por ejemplo, para la siguiente estructura for:
#
# for contador in range(1,6,1):
#
# print("#",end="")
#
# la función range(1,6,1) genera los números 1, 2, 3, 4, 5. Por lo cual, contador tomará cada uno de esos valores. La siguiente tabla muestra cómo va cambiando el valor de la variable contador (columna izquierda) junto con lo que va apareciendo en pantalla (columna derecha, entre paréntesis se muestran los símbolos que fueron impresos por pantalla en iteraciones anteriores):

# %%
Contador

# %%
Despliegue por pantalla

# %%
1

# %%
#

# %%
2

# %%
(#)#

# %%
3

# %%
(##)#

# %%
4

# %%
(###)#

# %%
5

# %%
(####)#

# %% [markdown]
# Al finalizar la ejecución del ciclo, en pantalla quedan desplegados 5 símbolos #.
#
# Nota que se podría realizar lo mismo, con un ciclo **while****de la siguiente manera:**

# %%
Ciclo implementado con Mientras

# %%
Equivalencia al ciclo Para

# %%
Contador=1

# %%
for contador in range(1,6,1)

# %%
while (contador<6):

# %%
    print("#",end="")

# %%
       print("#",end="")

# %%
       contador=contador+1

# %% [markdown]
# Sin embargo, el uso de **for** es más compacto (2 líneas en vez de 4 líneas para ciclo while).
#
# # PROBLEMAS** **PROPUESTOS
#
# Escribe un algoritmo que resuelva el siguiente problema: mostrar por pantalla los primeros 10 números pares. Resuelve este problema de 3 maneras distintas: usando ciclo while y ciclo for.
#
# Escribe un algoritmo que resuelva el siguiente problema: mostrar por pantalla las primeras 4 potencias de 2. Resuelve este problema de 3 maneras distintas: usando ciclo while, ciclo for.
#
# Escribe un algoritmo que resuelva el siguiente problema: mostrar por pantalla los primeros N números pares. N es un valor ingresado por el usuario. Resuelve este problema de 2 maneras distintas: usando ciclo while y ciclo for.
#
# Escribe un algoritmo que resuelva el siguiente problema: desplegar por pantalla todos los números enteros que existen entre los números A y B (ambos inclusive) que ingresa el usuario. Nota que si A es menor que B, se despliegan los números en orden creciente. Pero si A es mayor que B, los números se despliegan en orden decreciente. A continuación se muestran 2 ejemplos de la ejecución del algoritmo:
#
# Escribe un algoritmo en Python que emule la solicitud de clave en una cajero automático: si el usuario equivoca la clave 3 veces consecutivas, el cajero muestra el mensaje “Tarjeta retenida”, se “traga” la tarjeta (esta última acción no la puedes emular en Python ya que la instrucción “Tragar tarjeta” no existe) y termina la ejecución del algoritmo. Si el usuario logra ingresar la clave válida en uno de los 3 primeros intentos, entonces aparece el mensaje “Bienvenid@ al servicio”. Supón que la clave válida se encuentra almacenada en una variable.
#
# Escribe un algoritmo en Python que solicite números enteros al usuario y vaya calculando la suma de todos ellos. La solicitud de números al usuario termina cuando se ingresa un **-1**, en cuyo caso se muestra por pantalla el resultado de la suma. Está permitido que el usuario ingrese como primer valor un -1, en cuyo caso el algoritmo termina inmediatamente.
#
# Escribe el algoritmo que permite desplegar por pantalla los números pares que se encuentran entre dos números ingresados. El menor valor se almacena en la variable numInferior y el mayor en la variable numSuperior.
#
# Escribe en código un algoritmo que solicite al usuario el número de empleados de una empresa y luego calcule el salario a pagar a cada uno de ellos. Para ello, para cada empleado, debe solicitar los siguientes datos: nombre, número de horas semanales trabajadas por el empleador (NHT), valor de la hora trabajada (VHC).  Luego, el salario se calcula como NHT*VHC.
#
# Escribe el código de un algoritmo que solicita, de uno en uno, los datos de género de un grupo de personas y determina el porcentaje de hombres, mujeres y personas que no desean entregar esta información.  Para género masculino el usuario debe ingresar ‘m’ , ‘**f’** para el femenino y ‘n’ si no desea entregar esta información. El programa termina cuando se ingresa el caracter ‘**x**’.
#
# La figura de abajo representa las diferentes posiciones (identificadas con números dentro de círculos) por las que atraviesa una máquina de un casino muy especial, con la que se puede jugar con fichas del tipo **a,** **b,** **c** y **d**. Escribe el código de un algoritmo que, comenzando por la posición inicial **1****,** solicite una ficha a jugar en cada instante. Dependiendo del valor de la ficha, se va avanzando en las posiciones hasta intentar llegar a la posición final **4**. La siguiente posición de la máquina se determina a partir de la posición actual y la ficha que se inserta, y así sucesivamente.
#
# ![](assets/guia_03_ejercicios_ciclos/guia_03_ejercicios_ciclos_img01.png)
#
# Por ejemplo, si se está en la posición 1 y se ingresa una ficha a, se avanza a la posición 2 (se queda en 1 en otro caso).
#
# El juego termina cuando el usuario presiona n. En ese caso, si la máquina se encuentra en la posición 4, el usuario **gana el juego**. Si se encuentra en cualquier otra posición, pierde.
#
# Escribe el código de un algoritmo que calcule el factorial de un número ingresado. El factorial de un número **n** (denominado **n!**) se calcula como: **n*(n-1)*(n-2)*(n-3)*..1**.
#
# Escribe el código que calcula el resto de la división entre dos enteros positivos A y B, para A y B indicados por el usuario (sin usar el operador modulo).
#
# Escribe el código que permite determinar si un número entero positivo P es primo.  El valor de P se solicita al usuario.
#
# Escribe el código que permite resolver la siguiente serie: 1!+ 2! + 3! + …+ N!. El valor de N se solicita al usuario
#
# Realice un programa que determine si un número es palindrome. Un número palindrome es aquel que se lee de la misma manera de izquierda a derecha, como de derecha a izquierda, por ejemplo: 131 y 7887.
#
# Realice un programa que solicite números al usuario hasta que ingrese un 0 y devuelva el menor de todos los números ingresados que sean distintos a 0.
#
# Hoy en día todos los colegios quieren enseñar robótica. Pensando en eso, un grupo de alumnos de la UAI decide crear un robot que ayuda a los alumnos de colegio a aprender conceptos matemáticos tales como la distancia a un punto de origen. Para ello, el robot se ubica en un punto de partida y luego puede recibir los siguientes comandos de parte de los alumnos:
#
# ADELANTE → mueve el robot un espacio en la coordenada y
#
# ATRAS → retrocede el robot un espacio en la coordenada y
#
# DERECHA → mueve el robot un espacio en la coordenada x
#
# IZQUIERDA → retrocede el robot un espacio en la coordenada x
#
# DISTANCIA → calcula la distancia del robot respecto al origen
#
# SALIR → termina el programa
#
# El robot recibe un comando a la vez. Luego de recibir un comando, ejecuta la acción correspondiente y queda en espera del siguiente comando. Si el último comando ingresado fue SALIR, el robot no espera más comandos y se apaga.
#
# Por ejemplo, si el alumno ingresa los siguientes comandos (uno a la vez): ADELANTE, ADELANTE, DERECHA, ADELANTE, DERECHA, entonces al finalizar la ejecución del último comando el robot estará en la posición (2, 3), pues se movió 2 espacios a la derecha y 3 espacios hacia adelante. Por ende, si el alumno ingresa ahora el comando DISTANCIA, se deberá mostrar en pantalla el valor 3.6 (equivalente a la distancia euclidiana (d(p,q)=(px-qx)2+(py-qy)2)desde el origen hasta la posición actual del robot).
#
# Escribe un programa en Python que simule la operación del robot. Es decir, el programa debe recibir los comandos de parte de los alumnos hasta que el usuario ingrese el comando SALIR. Supón que el usuario no ingresa comando erróneos. A continuación se muestra un ejemplo de cómo debe operar el programa:

# %%
Bienvenido
Ingresa tu comando
ADELANTE
Ingresa tu comando
ADELANTE
Ingresa tu comando
DERECHA
Ingresa tu comando
DERECHA
Ingresa tu comando
ADELANTE
Ingresa tu comando
DISTANCIA
La distancia es: 3.605551275463989
Ingresa tu comando
SALIR

# %% [markdown]
# Escribe un programa en Python que le pida al usuario un número entero positivo n y luego le dé la posibilidad de elegir entre:
#
# calcular la suma de los números 1,… ,n (para ello, el usuario debe ingresar la palabra “suma”)
#
# calcular el producto de los números  1, ..., n (para ello, el usuario debe ingresar la palabra “producto”)
#
# Finalmente, el programa debe desplegar el resultado de la operación elegida por pantalla. Supón que el usuario no ingresa números erróneos.
#
# A continuación se muestran dos ejemplos de cómo debe operar el programa:

# %%
Ejemplo de suma

# %%
Ingresa un número:
7
Ingresa que operación deseas (suma, producto):
suma
El resultado de la suma es 28

# %%
Ejemplo de producto

# %%
Ingresa un número:
7
Ingresa que operación deseas (suma, producto):
producto
El producto de los números es 5040

# %% [markdown]
# Escriba un programa en Python que le pida al usuario un número n y despliegue los primeros n números naturales al cuadrado y luego su suma.
#
# Es decir, el programa debe preguntarle al usuario un número n y luego imprimir 1, 4, 9, ... , n**2 y el resultado de la suma en pantalla.
#
# Cree un programa que solicite al usuario un número entero positivo mayor a 1. En caso que el usuario no cumpla con la condición (es decir, no ingresa un número entero positivo mayor a 1), el programa debe seguir solicitando el número hasta que el usuario cumpla con la condición. Una vez que el usuario ha ingresado un número positivo mayor a 1, el programa debe descomponer el número ingresado en una multiplicación de números primos y desplegar estos números por pantalla.
#
# **Atención, la descomposición del número se debe realizar utilizando exclusivamente un solo ciclo** **while****.**
#
# El entrenador del equipo olímpico de maratón tiene como principal tarea obtener indicadores que permitan a sus corredores mejorar el rendimiento. Dado su alto conocimiento en programación, le ha encomendado a usted realizar un pequeño, pero muy importante programa que calcule el tiempo total (tt) que requiere un corredor en completar el trayecto completo. El sistema contempla una simple consideración. A medida que el corredor avanza, su rendimiento comienza a decaer y demora p% más en cubrir cada tramo.
#
# ![](assets/guia_03_ejercicios_ciclos/guia_03_ejercicios_ciclos_img02.png)
#
# Implemente un programa que calcule el tiempo total (tt) según los siguientes parámetros de entrada:
#
# d: Distancia del tramo expresada en n metros
#
# t0:  Tiempo que toma recorrer el primer tramo de n metros
#
# p: Porcentaje de aumento de tiempo al recorrer un tramo de n metros
#
# dt: Distancia total a recorrer
#
# La salida del programa debe ser tt, el tiempo total que demora el corredor en recorrer la distancia total. El último tramo podría no estar completo. Calcula el tiempo de manera proporcional.
#
# En física, el movimiento de un proyectil en un entorno idealizado sin resistencia del aire en el tiempo (t) para los ejes X e Y se puede determinar en forma analítica y precisa a través de las siguientes ecuaciones:
#
# x(t) = x0 + vx,o*t
#
# y(t) = y0 + vy,o*t – ½ * g * t2
#
# En las ecuaciones, g es la aceleración debida a la gravedad (9.8 m/s2). x0 e y0 son la posición inicial en el eje X e Y, respectivamente. vx,o y vy,o son la velocidad inicial en el eje X e Y, respectivamente.
#
# Además, dado un ángulo q (valor entre 0 y 360) y v (la velocidad inicial de un proyectil),  los valores de vx,o y vy,o pueden ser estimados a través de las siguientes ecuaciones:
#
# vx,o = v * cos(angulo_rad)
#
# vy,o = v * sen(angulo_rad)
#
# En las ecuaciones ang_rad es el ángulo en radianes (angulo_rad = q * p/180).
#
# Cree un programa en Python que solicite al usuario la velocidad inicial del objeto a lanzar (asuma el ingreso de valores correctos y que la velocidad corresponde a m/s) y determine el ángulo que maximice la distancia recorrida en el eje X después de 20 segundos (asuma x0=0 e y0=infinito). Para ello, pruebe todos los ángulos posibles desde el 0 hasta el 90 en intervalos de 1. Recuerde utilizar las funciones de math.
#
# Basado en el enunciado del ejercicio anterior, cree un programa en Python que solicite la velocidad y ángulo inicial de un objeto a lanzar (asuma el ingreso de valores correctos y que la velocidad corresponde a m/s) y determine la cantidad de tiempo que se demora el objeto en caer (asuma x0=0 e y0=0), y luego calcule la distancia total recorrida en el eje X. Para calcular el tiempo use valores decimales comenzando con 0.01 y aumento de 0.01.
